# %%
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from keras.utils import np_utils
import numpy as np
from keras import optimizers
from sklearn.model_selection import train_test_split
from sklearn import metrics
#Theano backend
from numpy import argmax
# Out:
# Using TensorFlow backend.

# %%
#load in the data set: 
jazz = pd.read_csv("../data/jazz_csv.csv")
classical = pd.read_csv("../data/classical_csv.csv")
country = pd.read_csv("../data/country_csv.csv")
edm = pd.read_csv("../data/edm_csv.csv")
rap = pd.read_csv("../data/rap_csv.csv")
rock = pd.read_csv("../data/rock_csv.csv")

# %%
count = 0
features = []
genres = []
dataframes = {1:jazz, 2: classical, 3:country, 4:edm, 5: rap, 6: rock} #map genre dfs to index
#dataframes = {1:jazz, 2: classical, 3:rock, 4:edm, 5: rap } #map genre dfs to index

for genre, dataframe in dataframes.items():
    count = 0
    for ind, row in dataframe.iterrows():
        count+=1
        #features.append([row["acousticness"], row["danceability"], row["energy"],row["loudness"], row["tempo"], row["valence"]])

        features.append([row["acousticness"],row["instrumentalness"], row["key"], row["danceability"], row["energy"],row["loudness"],row["speechiness"], row["tempo"], row["valence"]])
        genres.append(genre)
y = genres
X = features

# %%
encoder = LabelEncoder() #use encoder to hot encode the genres to flag the genre in matrix 
encoder.fit(y) 
encoded_Y = encoder.transform(y)
dummy_y = np_utils.to_categorical(encoded_Y) 
y = dummy_y

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 21) #split data 
X_train = [X_train]

# %%
model = Sequential() #use a sequential model bc we wanna keep adding layers potentially 
model.add(Dense(256, input_dim=9, activation='relu'))
model.add(Dense(128, activation='relu')) #four dense layers
model.add(Dense(64, activation='relu'))
model.add(Dense(6, activation='softmax'))
model.add(Dropout(128)) #dropout for overfitting data 
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) #use loss func for categorical and base on accuracy

# %%
model.fit(X_train, y_train, epochs=120, batch_size=128) #start with a baby amount
# Out:
# Epoch 1/120
# 10038/10038 [==============================] - 1s 139us/step - loss: 1.8412 - acc: 0.3151
# Epoch 2/120
# 10038/10038 [==============================] - 0s 42us/step - loss: 1.3757 - acc: 0.3877
# Epoch 3/120
# 10038/10038 [==============================] - 0s 42us/step - loss: 1.3076 - acc: 0.4185
# Epoch 4/120
# 10038/10038 [==============================] - 0s 44us/step - loss: 1.2509 - acc: 0.4604
# Epoch 5/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 1.2129 - acc: 0.4806
# Epoch 6/120
# 10038/10038 [==============================] - 0s 42us/step - loss: 1.1337 - acc: 0.5219
# Epoch 7/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 1.0891 - acc: 0.5358
# Epoch 8/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 1.0335 - acc: 0.5712
# Epoch 9/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 0.9990 - acc: 0.5859
# Epoch 10/120
# 10038/10038 [==============================] - 0s 47us/step - loss: 0.9684 - acc: 0.6002
# Epoch 11/120
# 10038/10038 [==============================] - 0s 48us/step - loss: 0.9112 - acc: 0.6324
# Epoch 12/120
# 10038/10038 [==============================] - 0s 44us/step - loss: 0.8936 - acc: 0.6350
# Epoch 13/120
# 10038/10038 [==============================] - 0s 47us/step - loss: 0.8749 - acc: 0.6424
# Epoch 14/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 0.8574 - acc: 0.6491
# Epoch 15/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 0.8345 - acc: 0.6654
# Epoch 16/120
# 10038/10038 [==============================] - 0s 44us/step - loss: 0.8391 - acc: 0.6627
# Epoch 17/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 0.8199 - acc: 0.6740
# Epoch 18/120
# 10038/10038 [==============================] - 0s 42us/step - loss: 0.8343 - acc: 0.6668
# Epoch 19/120
# 10038/10038 [==============================] - 0s 42us/step - loss: 0.7908 - acc: 0.6846
# Epoch 20/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 0.8179 - acc: 0.6683
# Epoch 21/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 0.7680 - acc: 0.6979
# Epoch 22/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 0.7843 - acc: 0.6832
# Epoch 23/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 0.8045 - acc: 0.6736
# Epoch 24/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.7901 - acc: 0.6834
# Epoch 25/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 0.7692 - acc: 0.6914
# Epoch 26/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 0.7771 - acc: 0.6887
# Epoch 27/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.7854 - acc: 0.6847
# Epoch 28/120
# 10038/10038 [==============================] - 1s 51us/step - loss: 0.7458 - acc: 0.7025
# Epoch 29/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 0.7482 - acc: 0.7021
# Epoch 30/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 0.7563 - acc: 0.6972
# Epoch 31/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 0.7612 - acc: 0.6980
# Epoch 32/120
# 10038/10038 [==============================] - 0s 44us/step - loss: 0.7392 - acc: 0.7045
# Epoch 33/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.7545 - acc: 0.6968
# Epoch 34/120
# 10038/10038 [==============================] - 0s 42us/step - loss: 0.7461 - acc: 0.7044
# Epoch 35/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 0.7582 - acc: 0.7026
# Epoch 36/120
# 10038/10038 [==============================] - 0s 44us/step - loss: 0.7455 - acc: 0.7007
# Epoch 37/120
# 10038/10038 [==============================] - 0s 44us/step - loss: 0.7407 - acc: 0.7037
# Epoch 38/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.7425 - acc: 0.7037
# Epoch 39/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.7438 - acc: 0.7040
# Epoch 40/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 0.7287 - acc: 0.7103
# Epoch 41/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.7263 - acc: 0.7071
# Epoch 42/120
# 10038/10038 [==============================] - 0s 42us/step - loss: 0.7369 - acc: 0.7023
# Epoch 43/120
# 10038/10038 [==============================] - 0s 44us/step - loss: 0.7416 - acc: 0.7032
# Epoch 44/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 0.7524 - acc: 0.6970
# Epoch 45/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 0.7167 - acc: 0.7168
# Epoch 46/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.7205 - acc: 0.7111
# Epoch 47/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 0.7114 - acc: 0.7158
# Epoch 48/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 0.7256 - acc: 0.7079
# Epoch 49/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 0.7125 - acc: 0.7149
# Epoch 50/120
# 10038/10038 [==============================] - 0s 42us/step - loss: 0.7186 - acc: 0.7132
# Epoch 51/120
# 10038/10038 [==============================] - 0s 47us/step - loss: 0.7371 - acc: 0.7041
# Epoch 52/120
# 10038/10038 [==============================] - 0s 42us/step - loss: 0.7238 - acc: 0.7107
# Epoch 53/120
# 10038/10038 [==============================] - 0s 42us/step - loss: 0.7255 - acc: 0.7130
# Epoch 54/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 0.6999 - acc: 0.7201
# Epoch 55/120
# 10038/10038 [==============================] - 0s 44us/step - loss: 0.7048 - acc: 0.7206
# Epoch 56/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.7102 - acc: 0.7166
# Epoch 57/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 0.7004 - acc: 0.7189
# Epoch 58/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 0.6994 - acc: 0.7237
# Epoch 59/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 0.7120 - acc: 0.7170
# Epoch 60/120
# 10038/10038 [==============================] - 1s 51us/step - loss: 0.7033 - acc: 0.7206
# Epoch 61/120
# 10038/10038 [==============================] - 1s 52us/step - loss: 0.6924 - acc: 0.7274: 0s - loss: 0.7286 - acc:
# Epoch 62/120
# 10038/10038 [==============================] - 0s 49us/step - loss: 0.7065 - acc: 0.7201
# Epoch 63/120
# 10038/10038 [==============================] - 1s 55us/step - loss: 0.7147 - acc: 0.7125
# Epoch 64/120
# 10038/10038 [==============================] - 0s 44us/step - loss: 0.6830 - acc: 0.7311
# Epoch 65/120
# 10038/10038 [==============================] - 1s 52us/step - loss: 0.6897 - acc: 0.7268
# Epoch 66/120
# 10038/10038 [==============================] - 0s 47us/step - loss: 0.6877 - acc: 0.7274
# Epoch 67/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.6995 - acc: 0.7228
# Epoch 68/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 0.6817 - acc: 0.7287
# Epoch 69/120
# 10038/10038 [==============================] - 0s 44us/step - loss: 0.6843 - acc: 0.7309
# Epoch 70/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 0.6888 - acc: 0.7299
# Epoch 71/120
# 10038/10038 [==============================] - 0s 48us/step - loss: 0.6838 - acc: 0.7302
# Epoch 72/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 0.6791 - acc: 0.7303
# Epoch 73/120
# 10038/10038 [==============================] - 0s 47us/step - loss: 0.6918 - acc: 0.7227
# Epoch 74/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.6853 - acc: 0.7257
# Epoch 75/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 0.6804 - acc: 0.7292
# Epoch 76/120
# 10038/10038 [==============================] - 0s 48us/step - loss: 0.6939 - acc: 0.7227
# Epoch 77/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.6689 - acc: 0.7348
# Epoch 78/120
# 10038/10038 [==============================] - 0s 48us/step - loss: 0.6902 - acc: 0.7277
# Epoch 79/120
# 10038/10038 [==============================] - 0s 49us/step - loss: 0.6810 - acc: 0.7309
# Epoch 80/120
# 10038/10038 [==============================] - 0s 49us/step - loss: 0.6840 - acc: 0.7283
# Epoch 81/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 0.6799 - acc: 0.7304
# Epoch 82/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 0.6807 - acc: 0.7315
# Epoch 83/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.6730 - acc: 0.7308
# Epoch 84/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.6653 - acc: 0.7380
# Epoch 85/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.6738 - acc: 0.7335
# Epoch 86/120
# 10038/10038 [==============================] - 0s 43us/step - loss: 0.6709 - acc: 0.7336
# Epoch 87/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.6700 - acc: 0.7329
# Epoch 88/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 0.6586 - acc: 0.7393
# Epoch 89/120
# 10038/10038 [==============================] - 0s 44us/step - loss: 0.6680 - acc: 0.7362: 0s - loss: 0.6522 - acc
# Epoch 90/120
# 10038/10038 [==============================] - 0s 44us/step - loss: 0.6572 - acc: 0.7401
# Epoch 91/120
# 10038/10038 [==============================] - 0s 44us/step - loss: 0.6587 - acc: 0.7403
# Epoch 92/120
# 10038/10038 [==============================] - 0s 44us/step - loss: 0.6602 - acc: 0.7386
# Epoch 93/120
# 10038/10038 [==============================] - 1s 50us/step - loss: 0.6849 - acc: 0.7272
# Epoch 94/120
# 10038/10038 [==============================] - 0s 49us/step - loss: 0.6574 - acc: 0.7432
# Epoch 95/120
# 10038/10038 [==============================] - 0s 49us/step - loss: 0.6583 - acc: 0.7422
# Epoch 96/120
# 10038/10038 [==============================] - 0s 44us/step - loss: 0.6686 - acc: 0.7354
# Epoch 97/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.6541 - acc: 0.7460
# Epoch 98/120
# 10038/10038 [==============================] - 1s 53us/step - loss: 0.6490 - acc: 0.7438
# Epoch 99/120
# 10038/10038 [==============================] - 0s 47us/step - loss: 0.6609 - acc: 0.7385
# Epoch 100/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 0.6480 - acc: 0.7433
# Epoch 101/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.6564 - acc: 0.7413
# Epoch 102/120
# 10038/10038 [==============================] - 0s 48us/step - loss: 0.6714 - acc: 0.7368
# Epoch 103/120
# 10038/10038 [==============================] - 0s 47us/step - loss: 0.6564 - acc: 0.7453
# Epoch 104/120
# 10038/10038 [==============================] - 0s 48us/step - loss: 0.6433 - acc: 0.7482
# Epoch 105/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 0.6532 - acc: 0.7433
# Epoch 106/120
# 10038/10038 [==============================] - 1s 55us/step - loss: 0.6537 - acc: 0.7431
# Epoch 107/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 0.6502 - acc: 0.7404
# Epoch 108/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.6502 - acc: 0.7426
# Epoch 109/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 0.6555 - acc: 0.7415
# Epoch 110/120
# 10038/10038 [==============================] - 0s 50us/step - loss: 0.6511 - acc: 0.7423
# Epoch 111/120
# 10038/10038 [==============================] - 0s 50us/step - loss: 0.6445 - acc: 0.7463
# Epoch 112/120
# 10038/10038 [==============================] - 0s 49us/step - loss: 0.6419 - acc: 0.7471
# Epoch 113/120
# 10038/10038 [==============================] - 0s 47us/step - loss: 0.6468 - acc: 0.7455
# Epoch 114/120
# 10038/10038 [==============================] - 0s 44us/step - loss: 0.6581 - acc: 0.7377
# Epoch 115/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 0.6415 - acc: 0.7460
# Epoch 116/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.6402 - acc: 0.7498
# Epoch 117/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.6539 - acc: 0.7403
# Epoch 118/120
# 10038/10038 [==============================] - 0s 44us/step - loss: 0.6348 - acc: 0.7536
# Epoch 119/120
# 10038/10038 [==============================] - 0s 45us/step - loss: 0.6397 - acc: 0.7508
# Epoch 120/120
# 10038/10038 [==============================] - 0s 46us/step - loss: 0.6478 - acc: 0.7418

# %%
_, accuracy = model.evaluate(X_train, y_train) 
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 10038/10038 [==============================] - 0s 44us/step
# Accuracy: 75.81

# %%
genres_dict = {0:"jazz", 1: "classical", 2:"country", 3:"edm", 4: "rap", 5: "rock"} #map genre dfs to index

# %%
test_y_predictions = model.predict([X_test])

# %%
ctr = 0
jazz_ctr, classical_ctr, country_ctr, edm_ctr , rap_ctr , rock_ctr = 0, 0, 0, 0, 0, 0
jazz_total, classical_total, country_total, edm_total, rap_total, rock_total = 0, 0, 0, 0, 0, 0

# %%
for i in range(len(test_y_predictions)):
    genre_predicted = genres_dict[argmax(test_y_predictions[i])]
    genre_expected = genres_dict[argmax(y_test[i])]
    print("predicted: ", genre_predicted, "expected: ", genre_expected)
    if genre_expected == 'jazz':
        jazz_total+=1
    elif genre_expected== 'classical':
        classical_total+=1
    elif genre_expected=='country':
        country_total+=1
    elif genre_expected=='edm':
        edm_total+=1
    elif genre_expected== 'rap':
        rap_total+=1
    elif genre_expected== 'rock':
        #print('______________________________')
        rock_total+=1
    if genre_predicted==genre_expected: 
        ctr+=1
        if genre_predicted == 'jazz':
            jazz_ctr+=1
        elif genre_predicted== 'classical':
            classical_ctr+=1
        elif genre_predicted=='country':
            country_ctr+=1
        elif genre_predicted=='edm':
            edm_ctr+=1
        elif genre_predicted== 'rap':
            rap_ctr+=1
        elif genre_predicted == 'rock':
            #print('yes')
            rock_ctr+=1
# Out:
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  rock expected:  jazz
# predicted:  edm expected:  country
# predicted:  rap expected:  rap
# predicted:  rock expected:  country
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  rock expected:  edm
# predicted:  edm expected:  edm
# predicted:  rock expected:  country
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  edm expected:  rock
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  edm expected:  rap
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  rap
# predicted:  edm expected:  rap
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  jazz
# predicted:  jazz expected:  rock
# predicted:  edm expected:  country
# predicted:  jazz expected:  rock
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  rock expected:  rock
# predicted:  edm expected:  country
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  country expected:  country
# predicted:  rap expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  country expected:  rock
# predicted:  rock expected:  rock
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  edm expected:  country
# predicted:  rock expected:  rock
# predicted:  edm expected:  rock
# predicted:  rock expected:  country
# predicted:  edm expected:  rap
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  edm expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  rap expected:  edm
# predicted:  jazz expected:  country
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  jazz expected:  classical
# predicted:  edm expected:  edm
# predicted:  jazz expected:  rap
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  jazz
# predicted:  rap expected:  rap
# predicted:  jazz expected:  rock
# predicted:  edm expected:  country
# predicted:  rap expected:  edm
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  rock expected:  jazz
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  rock expected:  country
# predicted:  jazz expected:  classical
# predicted:  rock expected:  rock
# predicted:  country expected:  country
# predicted:  country expected:  country
# predicted:  edm expected:  classical
# predicted:  country expected:  country
# predicted:  edm expected:  rap
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  country
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  country expected:  rock
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  rock expected:  jazz
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  country expected:  rock
# predicted:  country expected:  country
# predicted:  rock expected:  edm
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  classical expected:  jazz
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  classical expected:  jazz
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  jazz expected:  classical
# predicted:  classical expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  jazz
# predicted:  edm expected:  jazz
# predicted:  jazz expected:  rock
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  rap expected:  edm
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  country expected:  rock
# predicted:  classical expected:  jazz
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  jazz expected:  classical
# predicted:  edm expected:  rap
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  rap expected:  rock
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  rock expected:  jazz
# predicted:  edm expected:  edm
# predicted:  classical expected:  jazz
# predicted:  rap expected:  rap
# predicted:  edm expected:  jazz
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  rap expected:  edm
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  rock expected:  country
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  country expected:  rock
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  edm expected:  country
# predicted:  rock expected:  rock
# predicted:  country expected:  country
# predicted:  jazz expected:  rock
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  rap expected:  rock
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  jazz expected:  country
# predicted:  edm expected:  edm
# predicted:  jazz expected:  rock
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  edm expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  country
# predicted:  rap expected:  rock
# predicted:  rock expected:  jazz
# predicted:  edm expected:  country
# predicted:  edm expected:  rap
# predicted:  edm expected:  country
# predicted:  rap expected:  rap
# predicted:  rap expected:  edm
# predicted:  rock expected:  country
# predicted:  country expected:  country
# predicted:  edm expected:  rap
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  edm
# predicted:  country expected:  rock
# predicted:  classical expected:  classical
# predicted:  classical expected:  jazz
# predicted:  country expected:  rock
# predicted:  classical expected:  jazz
# predicted:  rock expected:  country
# predicted:  jazz expected:  edm
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  jazz expected:  rock
# predicted:  edm expected:  country
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  jazz
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  country expected:  jazz
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  classical expected:  jazz
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  rock expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  country
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  country
# predicted:  classical expected:  jazz
# predicted:  classical expected:  classical
# predicted:  rap expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  jazz expected:  rock
# predicted:  edm expected:  rock
# predicted:  rock expected:  country
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  edm expected:  rap
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  country expected:  rock
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  country
# predicted:  edm expected:  jazz
# predicted:  rock expected:  rock
# predicted:  rock expected:  rock
# predicted:  country expected:  jazz
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  jazz
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  country expected:  edm
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  jazz expected:  classical
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  rock expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  rock expected:  rock
# predicted:  jazz expected:  classical
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  edm expected:  country
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  country expected:  rap
# predicted:  classical expected:  jazz
# predicted:  rock expected:  jazz
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  jazz expected:  classical
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  edm expected:  rock
# predicted:  rock expected:  rock
# predicted:  country expected:  rock
# predicted:  country expected:  rock
# predicted:  classical expected:  jazz
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  rock expected:  rock
# predicted:  edm expected:  rock
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  country expected:  rock
# predicted:  rap expected:  edm
# predicted:  rock expected:  country
# predicted:  jazz expected:  classical
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  country expected:  rock
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  jazz expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  country expected:  rock
# predicted:  edm expected:  rap
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  classical expected:  jazz
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  rock expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  country
# predicted:  rap expected:  edm
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  jazz
# predicted:  rock expected:  country
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  rock expected:  edm
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  country expected:  rock
# predicted:  rock expected:  rock
# predicted:  rock expected:  rock
# predicted:  rock expected:  rock
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  classical
# predicted:  edm expected:  rap
# predicted:  rock expected:  rock
# predicted:  rock expected:  country
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  rap expected:  edm
# predicted:  classical expected:  classical
# predicted:  rock expected:  country
# predicted:  edm expected:  edm
# predicted:  rock expected:  rap
# predicted:  country expected:  country
# predicted:  edm expected:  rock
# predicted:  rock expected:  rock
# predicted:  jazz expected:  edm
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  country expected:  edm
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  country expected:  edm
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  country expected:  rock
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  rap expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  country
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  edm expected:  country
# predicted:  jazz expected:  rock
# predicted:  rap expected:  edm
# predicted:  jazz expected:  rock
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  rap expected:  edm
# predicted:  rap expected:  edm
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  rap expected:  edm
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  jazz expected:  classical
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  country expected:  jazz
# predicted:  edm expected:  rap
# predicted:  edm expected:  edm
# predicted:  rock expected:  country
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  edm
# predicted:  rap expected:  rap
# predicted:  rock expected:  country
# predicted:  classical expected:  classical
# predicted:  rock expected:  edm
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  jazz expected:  country
# predicted:  classical expected:  classical
# predicted:  country expected:  edm
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  rock expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  edm
# predicted:  rock expected:  country
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  edm expected:  rock
# predicted:  classical expected:  jazz
# predicted:  edm expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  country expected:  rap
# predicted:  rap expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  country
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  rap expected:  edm
# predicted:  rock expected:  rock
# predicted:  rock expected:  country
# predicted:  rock expected:  country
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  rock expected:  rock
# predicted:  jazz expected:  country
# predicted:  country expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  edm expected:  rock
# predicted:  classical expected:  jazz
# predicted:  classical expected:  rock
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  rock expected:  country
# predicted:  classical expected:  classical
# predicted:  jazz expected:  rock
# predicted:  rap expected:  rap
# predicted:  jazz expected:  classical
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  rap expected:  edm
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  edm expected:  rock
# predicted:  rap expected:  rap
# predicted:  edm expected:  rock
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  rap
# predicted:  edm expected:  rock
# predicted:  jazz expected:  edm
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  classical expected:  jazz
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  rock expected:  jazz
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  country expected:  rock
# predicted:  country expected:  rock
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  edm expected:  rock
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  rap expected:  country
# predicted:  rap expected:  rap
# predicted:  rock expected:  country
# predicted:  rock expected:  rock
# predicted:  country expected:  country
# predicted:  classical expected:  jazz
# predicted:  rock expected:  rock
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  edm expected:  rock
# predicted:  rock expected:  rock
# predicted:  rap expected:  edm
# predicted:  rock expected:  rock
# predicted:  rock expected:  jazz
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  country
# predicted:  jazz expected:  rock
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  edm expected:  rock
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  edm expected:  rap
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  rock expected:  country
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  jazz expected:  rock
# predicted:  edm expected:  edm
# predicted:  jazz expected:  classical
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  edm expected:  country
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  edm expected:  rock
# predicted:  country expected:  country
# predicted:  country expected:  country
# predicted:  jazz expected:  classical
# predicted:  country expected:  rock
# predicted:  country expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  country
# predicted:  rock expected:  rock
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  rock expected:  rock
# predicted:  edm expected:  rap
# predicted:  edm expected:  jazz
# predicted:  edm expected:  jazz
# predicted:  classical expected:  jazz
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  jazz expected:  rap
# predicted:  country expected:  rock
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  edm expected:  country
# predicted:  rap expected:  rap
# predicted:  country expected:  edm
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  edm expected:  rock
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  rap expected:  rock
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  jazz expected:  country
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  country
# predicted:  rap expected:  rock
# predicted:  rock expected:  rock
# predicted:  jazz expected:  country
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  rap expected:  edm
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  jazz expected:  rock
# predicted:  edm expected:  country
# predicted:  classical expected:  classical
# predicted:  rock expected:  country
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  rock expected:  jazz
# predicted:  edm expected:  country
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  rap expected:  edm
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  classical expected:  jazz
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  jazz expected:  rock
# predicted:  rock expected:  country
# predicted:  jazz expected:  country
# predicted:  classical expected:  classical
# predicted:  country expected:  rock
# predicted:  rock expected:  country
# predicted:  rap expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  country expected:  rock
# predicted:  edm expected:  edm
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  rap expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  rock expected:  rock
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  rap expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  country
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  country expected:  rap
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  edm expected:  rock
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  country expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  edm expected:  rap
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  country expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  edm expected:  rock
# predicted:  edm expected:  edm
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  rock expected:  jazz
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  country expected:  rap
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  edm
# predicted:  classical expected:  classical
# predicted:  classical expected:  jazz
# predicted:  country expected:  country
# predicted:  rock expected:  rock
# predicted:  rap expected:  rock
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  jazz expected:  classical
# predicted:  country expected:  country
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  rap expected:  jazz
# predicted:  rap expected:  rock
# predicted:  classical expected:  classical
# predicted:  rock expected:  jazz
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  rap expected:  edm
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  classical expected:  jazz
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  jazz expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  rap
# predicted:  classical expected:  jazz
# predicted:  edm expected:  edm
# predicted:  jazz expected:  classical
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  country expected:  rap
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  edm expected:  country
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  rap expected:  edm
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  rock expected:  edm
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  edm expected:  country
# predicted:  jazz expected:  jazz
# predicted:  country expected:  rock
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  country
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  country
# predicted:  edm expected:  country
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  jazz
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  rock expected:  edm
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rock
# predicted:  country expected:  country
# predicted:  country expected:  edm
# predicted:  rock expected:  country
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  country expected:  rock
# predicted:  rock expected:  edm
# predicted:  classical expected:  classical
# predicted:  rock expected:  rap
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  classical
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  rock expected:  country
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  country expected:  edm
# predicted:  rock expected:  country
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  edm expected:  rock
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  jazz expected:  rock
# predicted:  classical expected:  jazz
# predicted:  edm expected:  edm
# predicted:  classical expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  rock expected:  country
# predicted:  jazz expected:  edm
# predicted:  edm expected:  country
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  rock expected:  jazz
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  rock expected:  jazz
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  country
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  edm expected:  rap
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  edm expected:  country
# predicted:  country expected:  jazz
# predicted:  rap expected:  edm
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  edm expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  rock expected:  rock
# predicted:  country expected:  rap
# predicted:  classical expected:  classical
# predicted:  classical expected:  jazz
# predicted:  edm expected:  country
# predicted:  edm expected:  edm
# predicted:  country expected:  jazz
# predicted:  jazz expected:  classical
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  jazz expected:  classical
# predicted:  edm expected:  edm
# predicted:  rap expected:  edm
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  rock expected:  country
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  rap
# predicted:  rap expected:  rap
# predicted:  rock expected:  country
# predicted:  jazz expected:  rock
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  rock expected:  country
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  rap expected:  edm
# predicted:  classical expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  jazz expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  rap expected:  rock
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  rap expected:  edm
# predicted:  rock expected:  rock
# predicted:  country expected:  jazz
# predicted:  edm expected:  edm
# predicted:  rock expected:  country
# predicted:  classical expected:  classical
# predicted:  rap expected:  jazz
# predicted:  rap expected:  jazz
# predicted:  edm expected:  edm
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  jazz expected:  rock
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  rock expected:  jazz
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  edm expected:  rock
# predicted:  rap expected:  rock
# predicted:  edm expected:  country
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  edm expected:  rock
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  jazz expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  country
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  country expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  edm expected:  rap
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  jazz expected:  classical
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  country expected:  edm
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  country expected:  rap
# predicted:  classical expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  jazz
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  country
# predicted:  rock expected:  jazz
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  rock expected:  country
# predicted:  rock expected:  jazz
# predicted:  edm expected:  edm
# predicted:  rap expected:  rock
# predicted:  edm expected:  rock
# predicted:  country expected:  country
# predicted:  classical expected:  jazz
# predicted:  rap expected:  rap
# predicted:  rock expected:  country
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  edm
# predicted:  edm expected:  country
# predicted:  rap expected:  rap
# predicted:  rock expected:  edm
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  country expected:  rap
# predicted:  classical expected:  classical
# predicted:  edm expected:  country
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  rock expected:  jazz
# predicted:  rap expected:  rap
# predicted:  rock expected:  jazz
# predicted:  jazz expected:  rock
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  country expected:  country
# predicted:  country expected:  country
# predicted:  country expected:  country
# predicted:  rock expected:  rap
# predicted:  country expected:  rock
# predicted:  rock expected:  jazz
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  jazz expected:  country
# predicted:  rock expected:  rock
# predicted:  country expected:  country
# predicted:  rock expected:  country
# predicted:  rock expected:  jazz
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  rock expected:  rock
# predicted:  rock expected:  country
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  country expected:  edm
# predicted:  country expected:  rock
# predicted:  rock expected:  rock
# predicted:  country expected:  country
# predicted:  jazz expected:  rock
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  country expected:  edm
# predicted:  rock expected:  jazz
# predicted:  jazz expected:  rock
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  edm expected:  country
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  jazz
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  rock expected:  country
# predicted:  edm expected:  edm
# predicted:  edm expected:  country
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  country expected:  jazz
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  classical expected:  jazz
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  country expected:  rock
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  rap expected:  country
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  edm expected:  country
# predicted:  country expected:  country
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# ...
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  edm expected:  jazz
# predicted:  edm expected:  country
# predicted:  classical expected:  jazz
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  country expected:  rock
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  country
# predicted:  rap expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  edm expected:  jazz
# predicted:  rock expected:  country
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  rock expected:  country
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  rock expected:  rock
# predicted:  country expected:  edm
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  classical expected:  jazz
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  country expected:  rock
# predicted:  rock expected:  rock
# predicted:  rock expected:  country
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  edm
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  rock expected:  rock
# predicted:  jazz expected:  rock
# predicted:  rock expected:  rock
# predicted:  country expected:  edm
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  rock expected:  rock
# predicted:  country expected:  country
# predicted:  rock expected:  rock
# predicted:  rock expected:  rock
# predicted:  rap expected:  rock
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  jazz expected:  rock
# predicted:  rock expected:  rock
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  rock expected:  jazz
# predicted:  edm expected:  rap
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  country expected:  country
# predicted:  edm expected:  rock
# predicted:  classical expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  country
# predicted:  edm expected:  country
# predicted:  country expected:  rock
# predicted:  rock expected:  jazz
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  jazz expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  country
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  jazz expected:  classical
# predicted:  country expected:  country
# predicted:  jazz expected:  rock
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  country expected:  edm
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  rock expected:  country
# predicted:  classical expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  country
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  country
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  country expected:  rock
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  country expected:  rap
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  country
# predicted:  classical expected:  classical
# predicted:  country expected:  rock
# predicted:  rock expected:  rock
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  rock expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  classical
# predicted:  rock expected:  country
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  rap expected:  rock
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  jazz expected:  edm
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  classical expected:  jazz
# predicted:  rock expected:  jazz
# predicted:  jazz expected:  classical
# predicted:  rap expected:  rap
# predicted:  rock expected:  country
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  country expected:  edm
# predicted:  rock expected:  country
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  country expected:  rock
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  jazz expected:  rock
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  country expected:  rock
# predicted:  country expected:  rock
# predicted:  rock expected:  jazz
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  edm
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  country
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  rock
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  jazz expected:  country
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  edm
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  classical expected:  jazz
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  rock expected:  country
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  rock expected:  country
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  rock expected:  country
# predicted:  jazz expected:  classical
# predicted:  rap expected:  rap
# predicted:  edm expected:  country
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  country
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  classical expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  rock expected:  edm
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  classical expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  classical
# predicted:  rap expected:  rap
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  edm expected:  country
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rap
# predicted:  jazz expected:  country
# predicted:  rock expected:  country
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  rock expected:  country
# predicted:  rap expected:  classical
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  rock expected:  country
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  edm expected:  edm
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  rock
# predicted:  edm expected:  edm
# predicted:  rock expected:  country
# predicted:  edm expected:  rock
# predicted:  edm expected:  edm
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  rap expected:  rap
# predicted:  jazz expected:  rock
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  jazz expected:  jazz
# predicted:  edm expected:  edm
# predicted:  edm expected:  rap
# predicted:  rock expected:  rock
# predicted:  country expected:  country
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  country expected:  rock
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  edm
# predicted:  rap expected:  rap
# predicted:  classical expected:  classical
# predicted:  classical expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  classical
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  classical expected:  jazz
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  jazz
# predicted:  jazz expected:  rock
# predicted:  rock expected:  rock
# predicted:  rap expected:  edm
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  country
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  rap expected:  edm
# predicted:  classical expected:  classical
# predicted:  rap expected:  rap
# predicted:  rap expected:  edm
# predicted:  classical expected:  classical
# predicted:  edm expected:  country
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  rock expected:  rock
# predicted:  edm expected:  edm
# predicted:  country expected:  country
# predicted:  classical expected:  jazz
# predicted:  edm expected:  edm
# predicted:  edm expected:  country
# predicted:  jazz expected:  jazz
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  classical expected:  classical
# predicted:  edm expected:  country
# predicted:  rap expected:  rap
# predicted:  rap expected:  rap
# predicted:  edm expected:  edm
# predicted:  country expected:  rock
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  edm expected:  rap
# predicted:  edm expected:  rock
# predicted:  country expected:  country
# predicted:  country expected:  country
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  edm
# predicted:  rap expected:  edm
# predicted:  edm expected:  rock
# predicted:  rap expected:  rap
# predicted:  edm expected:  rap
# predicted:  rock expected:  country
# predicted:  country expected:  country
# predicted:  country expected:  country
# predicted:  classical expected:  classical
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  jazz
# predicted:  rock expected:  rock
# predicted:  rap expected:  rap
# predicted:  edm expected:  country
# predicted:  edm expected:  edm
# predicted:  rap expected:  rap
# predicted:  jazz expected:  jazz
# predicted:  jazz expected:  rock
# predicted:  jazz expected:  jazz
# predicted:  rock expected:  jazz
# predicted:  country expected:  country
# predicted:  rock expected:  rock
# predicted:  country expected:  jazz

# %%
print("jazz acc: ", jazz_ctr/jazz_total)
print("country acc: ", country_ctr/country_total)
print("rock acc: ", rock_ctr/rock_total)
print("rap acc: ", rap_ctr/rap_total)
print("classical acc: ", classical_ctr/classical_total)
print("edm acc: ", edm_ctr/edm_total)
print("overall acc: ", ctr/len(test_y_predictions))
# Out:
# jazz acc:  0.7260869565217392
# country acc:  0.6025316455696202
# rock acc:  0.6185819070904646
# rap acc:  0.8507462686567164
# classical acc:  0.9103448275862069
# edm acc:  0.7555012224938875
# overall acc:  0.7458167330677291
